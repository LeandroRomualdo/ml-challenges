# %% [markdown]
# ###### Instalação de bibliotecas para reprodução.

# %%
#!pip3 install seaborn
#!pip3 install pandas
#!pip3 install matplotlib
#!pip3 install numpy
#!pip3 install xgboost
#!pip3 install sklearn
#!pip3 install numpy
#!pip3 install pandas
#!pip3 install catboost

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from xgboost import XGBClassifier
from catboost import CatBoostClassifier
from sklearn.model_selection import cross_val_score
from sklearn.metrics import precision_recall_fscore_support as score
from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import mean_squared_error, mean_absolute_error, recall_score,classification_report,roc_curve,auc,precision_score, f1_score, cohen_kappa_score, confusion_matrix
from matplotlib import pyplot
import warnings 
from sklearn.preprocessing import LabelEncoder

warnings.simplefilter('ignore')

# %%
dataset = pd.read_csv("winequality.csv", sep=';')

# %% [markdown]
# ## Análise Exploratória

# %%
dataset.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    6497.000000       6497.000000  6497.000000     6497.000000
# mean        7.215307          0.339666     0.318633        5.443235
# std         1.296434          0.164636     0.145318        4.757804
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.400000          0.230000     0.250000        1.800000
# 50%         7.000000          0.290000     0.310000        3.000000
# 75%         7.700000          0.400000     0.390000        8.100000
# max        15.900000          1.580000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  6497.000000          6497.000000           6497.000000  6497.000000
# mean      0.056034            30.525319            115.744574     1.710882
# std       0.035034            17.749400             56.521855     7.636088
# min       0.009000             1.000000              6.000000     0.987110
# 25%       0.038000            17.000000             77.000000     0.992340
# 50%       0.047000            29.000000            118.000000     0.994890
# 75%       0.065000            41.000000            156.000000     0.996990
# max       0.611000           289.000000            440.000000   103.898000
#
#                 pH    sulphates      quality
# count  6497.000000  6497.000000  6497.000000
# mean      3.218501     0.531268     5.818378
# std       0.160787     0.148806     0.873255
# min       2.720000     0.220000     3.000000
# 25%       3.110000     0.430000     5.000000
# 50%       3.210000     0.510000     6.000000
# 75%       3.320000     0.600000     6.000000
# max       4.010000     2.000000     9.000000

# %% [markdown]
# ##### Dados Faltando

# %%
null_counts = dataset.isnull().sum()/len(dataset)
plt.figure(figsize=(10,5))
plt.xticks(np.arange(len(null_counts))+0.5,null_counts.index,rotation='vertical')
plt.ylabel('fraction of rows with missing data')
plt.bar(np.arange(len(null_counts)),null_counts)
# Out:
# <BarContainer object of 13 artists>

# %% [markdown]
# ##### Eliminando Outliers

# %% [markdown]
# A variável alcohol contém alguns valores descrepantes para muito acima da maioria dos valores desta variável, por isso foram eliminados para evitar que gerem ruidos nos modelos.
#
# outras variáveis como residual sugar, fixed acidity, volatile acidity, citric acid entre outras, foi aplicado uma função logaritmica para melhorar a distribuição dos valores das mesmas.

# %%
lista = ['128.933.333.333.333', '923.333.333.333.333','956.666.666.666.667','953.333.333.333.333',
            '963.333.333.333.333','973.333.333.333.333','120.666.666.666.667','100.333.333.333.333',
            '110.666.666.666.667','135.666.666.666.667','101.333.333.333.333','109.666.666.666.667',
            '105.666.666.666.667','117.333.333.333.333','112.666.666.666.667','123.333.333.333.333',
            '113.333.333.333.333','113.666.666.666.667','109.333.333.333.333','105.333.333.333.333',
            '114.333.333.333.333','100.333.333.333.333','114.666.666.666.667','116.333.333.333.333',
            '104.666.666.666.667','131.333.333.333.333']


df = dataset[~dataset['alcohol'].isin(lista)]

# %% [markdown]
# ##### Distribuição da variável target

# %%
target_counts = df.quality.value_counts()

sns.set(style="darkgrid")
target_counts.plot(kind='bar',title='Distribuição da variável preditora', color=['#1F77B4', '#FF7F0E'])

# %% [markdown]
# Como podemos ver no gráfico acima, temos um desbalanceamento entre as classes, onde claramente podemos ver que os valores mais presentes estão entre 5 e 7.

# %% [markdown]
# ##### Grafico de densidade

# %% [markdown]
# Este tipo de gráfico nos mostra a probabilidade de uma variável de valor contínua tomar determinada faixa de valor.

# %%
df.plot(kind='density',subplots=True,layout=(5,5), sharex=False, figsize=(16,16))
plt.show()

# %%
fig = plt.figure(figsize=(16,16))

p1 = fig.add_subplot(521)
p1 = sns.distplot(df['fixed acidity'])

p2 = fig.add_subplot(522)
p2 = sns.distplot(df['volatile acidity'])

p3 = fig.add_subplot(523)
p3 = sns.distplot(df['citric acid'])

p4 = fig.add_subplot(524)
p4 = sns.distplot(df['residual sugar'])

p5 = fig.add_subplot(525)
p5 = sns.distplot(df['chlorides'])

p6 = fig.add_subplot(526)
p6 = sns.distplot(df['free sulfur dioxide'])

p7 = fig.add_subplot(527)
p7 = sns.distplot(df['total sulfur dioxide'])

p8 = fig.add_subplot(528)
p8 = sns.distplot(df['density'])

p9 = fig.add_subplot(529)
p9 = sns.distplot(df['pH'])

plt.tight_layout()
fig = plt.gcf()

# %% [markdown]
# Vejamos a qualidade dos vinhos distribuidos na variável tipo (vermelho ou branco). Como podemos ver temos vinhos com melhor avaliados do tipo branco.

# %%
g = sns.catplot(y="quality", col="type", data=df, kind="count", height=6, aspect=.75);

# %% [markdown]
# Explorando a qualidade dos vinhos, podemos notar que vinhos com qualidade 8 e 9 tem menor densidade, mantém as menores taxas de acídez volátil e um vinho de qualidade 9 tem os maiores níveis de acídez cítrica e menos calorias. Os valores de ph são muito próximos para todos os níveis de qualidade.

# %%
fig = plt.figure(figsize = (10,6))
sns.barplot(x = 'quality', y = 'density', data = df)

# %%
fig = plt.figure(figsize = (10,6))
sns.barplot(x = 'quality', y = 'volatile acidity', data = df)

# %%
fig = plt.figure(figsize = (10,6))
sns.barplot(x = 'quality', y = 'citric acid', data = df)

# %%
fig = plt.figure(figsize = (10,6))
sns.barplot(x = 'quality', y = 'residual sugar', data = df)

# %%
fig = plt.figure(figsize = (10,6))
sns.barplot(x = 'quality', y = 'chlorides', data = df)

# %%
fig = plt.figure(figsize = (10,6))
sns.barplot(x = 'quality', y = 'pH', data = df)

# %%
dataset.sample(5)
# Out:
#        type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 2355  White            7.6              0.48         0.33             7.0
# 2945  White            4.9              0.33         0.31             1.2
# 1005  White            6.6              0.18         0.28             3.3
# 3230  White            6.7              0.13         0.57             6.6
# 5883    Red            7.4              0.58         0.00             2.0
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 2355      0.024                 14.0                 130.0  0.99180  3.25
# 2945      0.016                 39.0                 150.0  0.98713  3.33
# 1005      0.044                 18.0                  91.0  0.99300  3.42
# 3230      0.056                 60.0                 150.0  0.99548  2.96
# 5883      0.064                  7.0                  11.0  0.99562  3.45
#
#       sulphates alcohol  quality
# 2355       0.45    12.5        7
# 2945       0.59      14        8
# 1005       0.64    10.8        6
# 3230       0.43     9.4        6
# 5883       0.58    11.3        6

# %%
cols = ['residual sugar','fixed acidity','volatile acidity','citric acid','residual sugar', 'free sulfur dioxide',
       'total sulfur dioxide']

for c in cols:
    df[c] = round(np.log1p(df[c]),3)

# %% [markdown]
# Obs.: Foi utilzado a função de logaritmo com ponto flutuante no casos acima, pois em alguns casos eram gerados valores negativos, e como solução de contorno foi aplicado o log1p pois calcula o logaritmo natural acrescido de uma unidade.

# %% [markdown]
# ##### Transformação da variável "Type" para numérica.

# %%
df['type'] = pd.get_dummies(df['type'])

# %% [markdown]
# ##### Gráfico de correlação

# %%
sns.heatmap(df.corr())
plt.show()

# %% [markdown]
# ##### Alterando variável target para binária

# %% [markdown]
# Como vimos no gráfico de distribuição da variável target, temos um desbalanceamento entre as classes do dataset.
# Isso pode dificultar chegarmos a um modelo minimamente satisfatório, por isso a variável target foi alterada para binária.

# %%
bins = (1, 5.1, 9)
group_names = ['bad', 'good']
df['quality'] = pd.cut(df['quality'], bins = bins, labels = group_names)
df['quality'] = df['quality'].astype('str')
label_quality = LabelEncoder()
df['quality'] = label_quality.fit_transform(df['quality'])
df['quality'].value_counts()
# Out:
# 1    4082
# 0    2375
# Name: quality, dtype: int64

# %%
df['type'] = df['type'].astype('float64')
df['fixed acidity'] = df['fixed acidity'].astype('float64')
df['volatile acidity'] = df['volatile acidity'].astype('float64')
df['citric acid'] = df['citric acid'].astype('float64')
df['residual sugar'] = df['residual sugar'].astype('float64')
df['chlorides'] = df['chlorides'].astype('float64')
df['free sulfur dioxide'] = df['free sulfur dioxide'].astype('float64')
df['total sulfur dioxide'] = df['total sulfur dioxide'].astype('float64')
df['density'] = df['density'].astype('float64')
df['pH'] = df['pH'].astype('float64')
df['sulphates'] = df['sulphates'].astype('float64')
df['alcohol'] = df['alcohol'].astype('float64')

# %% [markdown]
# ##### Divisão dos dados entre treino, teste e validação

# %%
y = df.quality
x = df.drop('quality',axis=1)
X_train, X_test, y_train, y_test = train_test_split(x, y, random_state = 10)
X_valid, X_test, y_valid, y_test = train_test_split(X_test, y_test, random_state = 10)

# %% [markdown]
# ##### Modelos

# %% [markdown]
# Para o treinamento dos modelos foram escolhidos algoritmos baseados em árvores pois a relação entre as variáveis dependente e indepente não apresenta alta linearidade.
#
# Foi escolhido random forest pela versatilidade e poder de lidar com dados de muitas dimensões.
#
# Além de algorítmos que convertem aprendizado fraco em aprendizado forte (boosting) combinando previsões de várias pequenas árvores.

# %% [markdown]
# ##### Grid Search

# %% [markdown]
# Nesta fase pré-treinamento dos modelos, estamos procurando os melhores parâmetros para nossos algoritmos, neste caso usaremos Random Forest, Adaboosting, XGBoost e Gradient Boosting.
#
# E para descobrir a melhor combinação de parâmetros, vamos usar o grid search para os ajudar.

# %%
# Thanks for the David batista posted class on "http://www.davidsbatista.net/blog/2018/02/23/model_optimization/"
class EstimatorSelectionHelper:

    def __init__(self, models, params):
        if not set(models.keys()).issubset(set(params.keys())):
            missing_params = list(set(models.keys()) - set(params.keys()))
            raise ValueError("Alguns estimadores estão com parâmetros ausentes: %s" % missing_params)
        self.models = models
        self.params = params
        self.keys = models.keys()
        self.grid_searches = {}

    def fit(self, X, y, cv=3, n_jobs=2, verbose=1, scoring=None, refit=False):
        for key in self.keys:
            print("Executando GridSearchCV em %s." % key)
            model = self.models[key]
            params = self.params[key]
            gs = GridSearchCV(model, params, cv=cv, n_jobs=n_jobs,
                              verbose=verbose, scoring=scoring, refit=refit,
                              return_train_score=True)
            gs.fit(X,y)
            self.grid_searches[key] = gs    

    def score_summary(self, sort_by='mean_score'):
        def row(key, scores, params):
            d = {
                 'estimator': key,
                 'min_score': min(scores),
                 'max_score': max(scores),
                 'mean_score': np.mean(scores),
                 'std_score': np.std(scores),
            }
            return pd.Series({**params,**d})

        rows = []
        for k in self.grid_searches:
            print(k)
            params = self.grid_searches[k].cv_results_['params']
            scores = []
            for i in range(self.grid_searches[k].cv):
                key = "split{}_test_score".format(i)
                r = self.grid_searches[k].cv_results_[key]        
                scores.append(r.reshape(len(params),1))

            all_scores = np.hstack(scores)
            for p, s in zip(params,all_scores):
                rows.append((row(k, s, p)))

        df = pd.concat(rows, axis=1).T.sort_values([sort_by], ascending=False)

        columns = ['estimator', 'min_score', 'mean_score', 'max_score', 'std_score']
        columns = columns + [c for c in df.columns if c not in columns]

        return df[columns]

# %%
models = {
    'RandomForestClassifier': RandomForestClassifier(),
    'AdaBoostClassifier': AdaBoostClassifier(),
    'GradientBoostingClassifier' : GradientBoostingClassifier(),
    'XGBoostClassifier' : XGBClassifier(),
    'CatBoostClassifier' : CatBoostClassifier()
}

params = {
    'RandomForestClassifier': { 'n_estimators': [100, 120, 300, 500, 800, 1200]},
    
    
    'AdaBoostClassifier':  { 'n_estimators': [100, 120, 300, 500, 800, 1200],
                           'learning_rate': [0.5, 0.7, 0.8, 1.0]},
    
    
    'GradientBoostingClassifier': { 'n_estimators': [100, 120, 300, 500, 800, 1200],
                                   'learning_rate': [0.5, 0.7, 0.8, 1.0]},
    
    'XGBoostClassifier' : {'n_estimators': [100, 120, 300, 500, 800, 1200],
                                   'learning_rate': [0.5, 0.7, 0.8, 1.0]},
    
    'CatBoostClassifier' : {'n_estimators': [100, 120, 300, 500, 800, 1200],
                                   'learning_rate': [0.5, 0.7, 0.8, 1.0]}
    
}

# %%
helper = EstimatorSelectionHelper(models, params)
helper.fit(X_train, y_train, scoring='f1', n_jobs=4)
# Out:
# Executando GridSearchCV em RandomForestClassifier.
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  30 out of  30 | elapsed:  1.2min finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# Executando GridSearchCV em AdaBoostClassifier.
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:   50.2s
# [Parallel(n_jobs=4)]: Done 120 out of 120 | elapsed:  2.9min finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# Executando GridSearchCV em GradientBoostingClassifier.
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:   29.3s
# [Parallel(n_jobs=4)]: Done 120 out of 120 | elapsed:  1.7min finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# Executando GridSearchCV em XGBoostClassifier.
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:   49.4s
# [Parallel(n_jobs=4)]: Done 120 out of 120 | elapsed:  2.4min finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# Executando GridSearchCV em CatBoostClassifier.
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed: 11.1min
# [Parallel(n_jobs=4)]: Done 120 out of 120 | elapsed: 45.5min finished

# %%
helper.score_summary(sort_by='max_score')
# Out:
# RandomForestClassifier
# AdaBoostClassifier
# GradientBoostingClassifier
# XGBoostClassifier
# CatBoostClassifier
#                  estimator min_score mean_score max_score   std_score  \
# 0   RandomForestClassifier  0.849725   0.858896  0.867355   0.0056779
# 1   RandomForestClassifier  0.853914    0.85868  0.865079   0.0037543
# 4   RandomForestClassifier  0.853248   0.857944  0.864608  0.00371553
# 3   RandomForestClassifier  0.855538   0.859259  0.863636  0.00347719
# 2   RandomForestClassifier   0.85113   0.857697  0.863275  0.00438565
# ..                     ...       ...        ...       ...         ...
# 28      AdaBoostClassifier  0.803783   0.808832  0.818182  0.00501102
# 22      AdaBoostClassifier  0.803162   0.810496  0.816836  0.00526334
# 26      AdaBoostClassifier  0.804124   0.809274     0.816  0.00442238
# 24      AdaBoostClassifier  0.800955   0.809553  0.815705  0.00592347
# 29      AdaBoostClassifier  0.801569   0.804915  0.809639  0.00270519
#
#    learning_rate n_estimators
# 0            NaN          100
# 1            NaN          120
# 4            NaN          800
# 3            NaN          500
# 2            NaN          300
# ..           ...          ...
# 28             1          800
# 22           0.8          800
# 26             1          300
# 24             1          100
# 29             1         1200
#
# [102 rows x 7 columns]

# %%
models = [
    RandomForestClassifier(n_estimators=100),
    GradientBoostingClassifier(learning_rate=0.5, n_estimators=800),
    AdaBoostClassifier(n_estimators=120, learning_rate=0.7),
    XGBClassifier(n_estimators=1200, learning_rate=0.8),
    CatBoostClassifier(n_estimators=300, learning_rate=0.7)
]
CV = 35
cv_df = pd.DataFrame(index=range(CV * len(models)))
entries = []
for model in models:
  model_name = model.__class__.__name__
  accuracies = cross_val_score(model
# 92:	learn: 0.1525013	total: 1.18s	remaining: 2.63s
# 93:	learn: 0.1502652	total: 1.19s	remaining: 2.62s
# 94:	learn: 0.1483062	total: 1.21s	remaining: 2.61s
# 95:	learn: 0.1460204	total: 1.22s	remaining: 2.6s
# 96:	learn: 0.1439032	total: 1.24s	remaining: 2.59s
# 97:	learn: 0.1426645	total: 1.25s	remaining: 2.57s
# 98:	learn: 0.1418306	total: 1.26s	remaining: 2.56s
# 99:	learn: 0.1405969	total: 1.27s	remaining: 2.55s
# 100:	learn: 0.1397430	total: 1.29s	remaining: 2.54s
# 101:	learn: 0.1383417	total: 1.3s	remaining: 2.52s
# 102:	learn: 0.1372174	total: 1.31s	remaining: 2.51s
# 103:	learn: 0.1353195	total: 1.32s	remaining: 2.5s
# 104:	learn: 0.1329716	total: 1.34s	remaining: 2.48s
# 105:	learn: 0.1319162	total: 1.35s	remaining: 2.47s
# 106:	learn: 0.1299940	total: 1.37s	remaining: 2.47s
# 107:	learn: 0.1293110	total: 1.38s	remaining: 2.45s
# 108:	learn: 0.1283548	total: 1.39s	remaining: 2.43s
# 109:	learn: 0.1272665	total: 1.4s	remaining: 2.42s
# 110:	learn: 0.1256570	total: 1.41s	remaining: 2.41s
# 111:	learn: 0.1245010	total: 1.42s	remaining: 2.39s
# 112:	learn: 0.1235336	total: 1.44s	remaining: 2.38s
# 113:	learn: 0.1222967	total: 1.46s	remaining: 2.38s
# 114:	learn: 0.1215051	total: 1.47s	remaining: 2.37s
# 115:	learn: 0.1202576	total: 1.48s	remaining: 2.35s
# 116:	learn: 0.1190260	total: 1.5s	remaining: 2.34s
# 117:	learn: 0.1182972	total: 1.5s	remaining: 2.32s
# 118:	learn: 0.1172198	total: 1.52s	remaining: 2.31s
# 119:	learn: 0.1166347	total: 1.53s	remaining: 2.29s
# 120:	learn: 0.1159199	total: 1.54s	remaining: 2.28s
# 121:	learn: 0.1144561	total: 1.55s	remaining: 2.27s
# 122:	learn: 0.1137681	total: 1.56s	remaining: 2.25s
# 123:	learn: 0.1132820	total: 1.58s	remaining: 2.24s
# 124:	learn: 0.1117132	total: 1.59s	remaining: 2.22s
# 125:	learn: 0.1107230	total: 1.6s	remaining: 2.21s
# 126:	learn: 0.1090205	total: 1.61s	remaining: 2.2s
# 127:	learn: 0.1069887	total: 1.63s	remaining: 2.19s
# 128:	learn: 0.1063433	total: 1.64s	remaining: 2.18s
# 129:	learn: 0.1053702	total: 1.65s	remaining: 2.16s
# 130:	learn: 0.1045368	total: 1.66s	remaining: 2.15s
# 131:	learn: 0.1038169	total: 1.68s	remaining: 2.13s
# 132:	learn: 0.1023072	total: 1.69s	remaining: 2.12s
# 133:	learn: 0.1013662	total: 1.7s	remaining: 2.11s
# 134:	learn: 0.1006339	total: 1.71s	remaining: 2.09s
# 135:	learn: 0.0995871	total: 1.73s	remaining: 2.08s
# 136:	learn: 0.0979557	total: 1.75s	remaining: 2.08s
# 137:	learn: 0.0976319	total: 1.76s	remaining: 2.07s
# 138:	learn: 0.0974574	total: 1.77s	remaining: 2.05s
# 139:	learn: 0.0966064	total: 1.8s	remaining: 2.06s
# 140:	learn: 0.0959593	total: 1.81s	remaining: 2.04s
# 141:	learn: 0.0952290	total: 1.82s	remaining: 2.03s
# 142:	learn: 0.0944841	total: 1.84s	remaining: 2.02s
# 143:	learn: 0.0933045	total: 1.85s	remaining: 2.01s
# 144:	learn: 0.0931498	total: 1.86s	remaining: 1.99s
# 145:	learn: 0.0925138	total: 1.88s	remaining: 1.98s
# 146:	learn: 0.0911042	total: 1.89s	remaining: 1.97s
# 147:	learn: 0.0904427	total: 1.9s	remaining: 1.95s
# 148:	learn: 0.0888555	total: 1.92s	remaining: 1.94s
# 149:	learn: 0.0880998	total: 1.93s	remaining: 1.93s
# 150:	learn: 0.0870472	total: 1.95s	remaining: 1.92s
# 151:	learn: 0.0865826	total: 1.97s	remaining: 1.92s
# 152:	learn: 0.0858167	total: 1.98s	remaining: 1.9s
# 153:	learn: 0.0852707	total: 2s	remaining: 1.9s
# 154:	learn: 0.0845216	total: 2.02s	remaining: 1.89s
# 155:	learn: 0.0833556	total: 2.04s	remaining: 1.88s
# 156:	learn: 0.0827740	total: 2.05s	remaining: 1.87s
# 157:	learn: 0.0817013	total: 2.07s	remaining: 1.86s
# 158:	learn: 0.0810548	total: 2.08s	remaining: 1.84s
# 159:	learn: 0.0804429	total: 2.09s	remaining: 1.83s
# 160:	learn: 0.0796781	total: 2.1s	remaining: 1.82s
# 161:	learn: 0.0786965	total: 2.12s	remaining: 1.8s
# 162:	learn: 0.0780546	total: 2.13s	remaining: 1.79s
# 163:	learn: 0.0772741	total: 2.15s	remaining: 1.78s
# 164:	learn: 0.0764584	total: 2.16s	remaining: 1.77s
# 165:	learn: 0.0758370	total: 2.17s	remaining: 1.75s
# 166:	learn: 0.0748414	total: 2.19s	remaining: 1.75s
# 167:	learn: 0.0742807	total: 2.2s	remaining: 1.73s
# 168:	learn: 0.0736446	total: 2.22s	remaining: 1.72s
# 169:	learn: 0.0728160	total: 2.23s	remaining: 1.71s
# 170:	learn: 0.0721616	total: 2.25s	remaining: 1.7s
# 171:	learn: 0.0715235	total: 2.28s	remaining: 1.69s
# 172:	learn: 0.0710329	total: 2.29s	remaining: 1.68s
# 173:	learn: 0.0702626	total: 2.31s	remaining: 1.67s
# 174:	learn: 0.0696990	total: 2.32s	remaining: 1.66s
# 175:	learn: 0.0690353	total: 2.34s	remaining: 1.65s
# 176:	learn: 0.0687917	total: 2.35s	remaining: 1.63s
# 177:	learn: 0.0682811	total: 2.36s	remaining: 1.62s
# 178:	learn: 0.0674809	total: 2.37s	remaining: 1.6s
# 179:	learn: 0.0662212	total: 2.39s	remaining: 1.59s
# 180:	learn: 0.0652541	total: 2.4s	remaining: 1.58s
# 181:	learn: 0.0647314	total: 2.41s	remaining: 1.56s
# 182:	learn: 0.0642185	total: 2.42s	remaining: 1.55s
# 183:	learn: 0.0637754	total: 2.44s	remaining: 1.54s
# 118:	learn: 0.1121529	total: 1.5s	remaining: 2.28s
# 119:	learn: 0.1106608	total: 1.51s	remaining: 2.27s
# 120:	learn: 0.1094193	total: 1.52s	remaining: 2.25s
# 121:	learn: 0.1081307	total: 1.53s	remaining: 2.24s
# 122:	learn: 0.1073723	total: 1.55s	remaining: 2.23s
# 123:	learn: 0.1062012	total: 1.56s	remaining: 2.22s
# 124:	learn: 0.1050981	total: 1.57s	remaining: 2.2s
# 125:	learn: 0.1036337	total: 1.59s	remaining: 2.19s
# 126:	learn: 0.1020508	total: 1.6s	remaining: 2.18s
# 127:	learn: 0.1008606	total: 1.61s	remaining: 2.17s
# 128:	learn: 0.1000879	total: 1.62s	remaining: 2.15s
# 129:	learn: 0.0989403	total: 1.64s	remaining: 2.14s
# 130:	learn: 0.0979123	total: 1.65s	remaining: 2.13s
# 131:	learn: 0.0966144	total: 1.66s	remaining: 2.11s
# 132:	learn: 0.0955890	total: 1.67s	remaining: 2.1s
# 133:	learn: 0.0949046	total: 1.69s	remaining: 2.09s
# 134:	learn: 0.0944996	total: 1.7s	remaining: 2.07s
# 135:	learn: 0.0933025	total: 1.71s	remaining: 2.06s
# 136:	learn: 0.0925543	total: 1.72s	remaining: 2.04s
# 137:	learn: 0.0922646	total: 1.73s	remaining: 2.03s
# 138:	learn: 0.0916520	total: 1.74s	remaining: 2.02s
# 139:	learn: 0.0907272	total: 1.75s	remaining: 2s
# 140:	learn: 0.0896429	total: 1.77s	remaining: 1.99s
# 141:	learn: 0.0883914	total: 1.78s	remaining: 1.98s
# 142:	learn: 0.0877748	total: 1.79s	remaining: 1.97s
# 143:	learn: 0.0862738	total: 1.8s	remaining: 1.95s
# 144:	learn: 0.0856550	total: 1.82s	remaining: 1.94s
# 145:	learn: 0.0852537	total: 1.83s	remaining: 1.93s
# 146:	learn: 0.0843565	total: 1.84s	remaining: 1.92s
# 147:	learn: 0.0834625	total: 1.85s	remaining: 1.9s
# 148:	learn: 0.0826420	total: 1.87s	remaining: 1.89s
# 149:	learn: 0.0819643	total: 1.88s	remaining: 1.88s
# 150:	learn: 0.0808916	total: 1.9s	remaining: 1.87s
# 151:	learn: 0.0801286	total: 1.91s	remaining: 1.86s
# 152:	learn: 0.0793898	total: 1.92s	remaining: 1.84s
# 153:	learn: 0.0789143	total: 1.93s	remaining: 1.83s
# 154:	learn: 0.0780908	total: 1.94s	remaining: 1.82s
# 155:	learn: 0.0772589	total: 1.95s	remaining: 1.8s
# 156:	learn: 0.0762717	total: 1.96s	remaining: 1.79s
# 157:	learn: 0.0753139	total: 1.98s	remaining: 1.78s
# 158:	learn: 0.0745068	total: 1.99s	remaining: 1.76s
# 159:	learn: 0.0740009	total: 2s	remaining: 1.75s
# 160:	learn: 0.0731919	total: 2.01s	remaining: 1.74s
# 161:	learn: 0.0723174	total: 2.03s	remaining: 1.73s
# 162:	learn: 0.0718077	total: 2.04s	remaining: 1.72s
# 163:	learn: 0.0711989	total: 2.06s	remaining: 1.7s
# 164:	learn: 0.0705052	total: 2.06s	remaining: 1.69s
# 165:	learn: 0.0699574	total: 2.08s	remaining: 1.68s
# 166:	learn: 0.0694802	total: 2.09s	remaining: 1.66s
# 167:	learn: 0.0686680	total: 2.1s	remaining: 1.65s
# 168:	learn: 0.0677256	total: 2.11s	remaining: 1.64s
# 169:	learn: 0.0674183	total: 2.13s	remaining: 1.63s
# 170:	learn: 0.0669101	total: 2.14s	remaining: 1.61s
# 171:	learn: 0.0660333	total: 2.15s	remaining: 1.6s
# 172:	learn: 0.0652935	total: 2.16s	remaining: 1.59s
# 173:	learn: 0.0646707	total: 2.17s	remaining: 1.57s
# 174:	learn: 0.0641733	total: 2.19s	remaining: 1.56s
# 175:	learn: 0.0636350	total: 2.2s	remaining: 1.55s
# 176:	learn: 0.0629750	total: 2.21s	remaining: 1.53s
# 177:	learn: 0.0625669	total: 2.22s	remaining: 1.52s
# 178:	learn: 0.0619313	total: 2.23s	remaining: 1.51s
# 179:	learn: 0.0614370	total: 2.25s	remaining: 1.5s
# 180:	learn: 0.0611650	total: 2.26s	remaining: 1.49s
# 181:	learn: 0.0606102	total: 2.27s	remaining: 1.47s
# 182:	learn: 0.0603833	total: 2.29s	remaining: 1.46s
# 183:	learn: 0.0598033	total: 2.3s	remaining: 1.45s
# 184:	learn: 0.0592683	total: 2.31s	remaining: 1.44s
# 185:	learn: 0.0589909	total: 2.32s	remaining: 1.42s
# 186:	learn: 0.0585615	total: 2.33s	remaining: 1.41s
# 187:	learn: 0.0583061	total: 2.35s	remaining: 1.4s
# 188:	learn: 0.0579809	total: 2.36s	remaining: 1.38s
# 189:	learn: 0.0572696	total: 2.37s	remaining: 1.37s
# 190:	learn: 0.0566543	total: 2.38s	remaining: 1.36s
# 191:	learn: 0.0559790	total: 2.4s	remaining: 1.35s
# 192:	learn: 0.0556774	total: 2.41s	remaining: 1.33s
# 193:	learn: 0.0552119	total: 2.42s	remaining: 1.32s
# 194:	learn: 0.0543492	total: 2.43s	remaining: 1.31s
# 195:	learn: 0.0537890	total: 2.44s	remaining: 1.3s
# 196:	learn: 0.0533048	total: 2.46s	remaining: 1.29s
# 197:	learn: 0.0529758	total: 2.47s	remaining: 1.27s
# 198:	learn: 0.0526321	total: 2.48s	remaining: 1.26s
# 199:	learn: 0.0520633	total: 2.5s	remaining: 1.25s
# 200:	learn: 0.0517062	total: 2.51s	remaining: 1.24s
# 201:	learn: 0.0513332	total: 2.52s	remaining: 1.22s
# 202:	learn: 0.0508861	total: 2.53s	remaining: 1.21s
# 203:	learn: 0.0502800	total: 2.55s	remaining: 1.2s
# 204:	learn: 0.0498514	total: 2.56s	remaining: 1.19s
# 205:	learn: 0.0494912	total: 2.57s	remaining: 1.17s
# 206:	learn: 0.0492914	total: 2.58s	remaining: 1.16s
# 207:	learn: 0.0490878	total: 2.6s	remaining: 1.15s
# 208:	learn: 0.0484466	total: 2.61s	remaining: 1.14s
# 209:	learn: 0.0481652	total: 2.62s	remaining: 1.12s
# 210:	learn: 0.0478476	total: 2.63s	remaining: 1.11s
# 52:	learn: 0.2291458	total: 650ms	remaining: 3.03s
# 53:	learn: 0.2270009	total: 663ms	remaining: 3.02s
# 54:	learn: 0.2251426	total: 676ms	remaining: 3.01s
# 55:	learn: 0.2235966	total: 687ms	remaining: 2.99s
# 56:	learn: 0.2211012	total: 697ms	remaining: 2.97s
# 57:	learn: 0.2188961	total: 709ms	remaining: 2.96s
# 58:	learn: 0.2177613	total: 721ms	remaining: 2.95s
# 59:	learn: 0.2165253	total: 734ms	remaining: 2.94s
# 60:	learn: 0.2151622	total: 744ms	remaining: 2.92s
# 61:	learn: 0.2128918	total: 758ms	remaining: 2.91s
# 62:	learn: 0.2096606	total: 770ms	remaining: 2.9s
# 63:	learn: 0.2074720	total: 780ms	remaining: 2.88s
# 64:	learn: 0.2060781	total: 793ms	remaining: 2.87s
# 65:	learn: 0.2028111	total: 808ms	remaining: 2.86s
# 66:	learn: 0.2001542	total: 821ms	remaining: 2.85s
# 67:	learn: 0.1965997	total: 834ms	remaining: 2.85s
# 68:	learn: 0.1954174	total: 842ms	remaining: 2.82s
# 69:	learn: 0.1930326	total: 857ms	remaining: 2.81s
# 70:	learn: 0.1894498	total: 870ms	remaining: 2.81s
# 71:	learn: 0.1868720	total: 882ms	remaining: 2.79s
# 72:	learn: 0.1844630	total: 892ms	remaining: 2.77s
# 73:	learn: 0.1805578	total: 906ms	remaining: 2.77s
# 74:	learn: 0.1787060	total: 918ms	remaining: 2.75s
# 75:	learn: 0.1774356	total: 930ms	remaining: 2.74s
# 76:	learn: 0.1746990	total: 941ms	remaining: 2.73s
# 77:	learn: 0.1730874	total: 955ms	remaining: 2.72s
# 78:	learn: 0.1706607	total: 969ms	remaining: 2.71s
# 79:	learn: 0.1683361	total: 983ms	remaining: 2.7s
# 80:	learn: 0.1667768	total: 996ms	remaining: 2.69s
# 81:	learn: 0.1643469	total: 1s	remaining: 2.67s
# 82:	learn: 0.1628374	total: 1.02s	remaining: 2.66s
# 83:	learn: 0.1604282	total: 1.03s	remaining: 2.65s
# 84:	learn: 0.1580670	total: 1.04s	remaining: 2.64s
# 85:	learn: 0.1562515	total: 1.05s	remaining: 2.62s
# 86:	learn: 0.1552593	total: 1.07s	remaining: 2.61s
# 87:	learn: 0.1540296	total: 1.08s	remaining: 2.6s
# 88:	learn: 0.1516790	total: 1.09s	remaining: 2.59s
# 89:	learn: 0.1498280	total: 1.1s	remaining: 2.58s
# 90:	learn: 0.1489496	total: 1.12s	remaining: 2.56s
# 91:	learn: 0.1473350	total: 1.13s	remaining: 2.56s
# 92:	learn: 0.1465245	total: 1.14s	remaining: 2.54s
# 93:	learn: 0.1437827	total: 1.15s	remaining: 2.52s
# 94:	learn: 0.1427405	total: 1.18s	remaining: 2.54s
# 95:	learn: 0.1415788	total: 1.19s	remaining: 2.52s
# 96:	learn: 0.1408371	total: 1.2s	remaining: 2.51s
# 97:	learn: 0.1393221	total: 1.22s	remaining: 2.51s
# 98:	learn: 0.1376559	total: 1.23s	remaining: 2.5s
# 99:	learn: 0.1357600	total: 1.24s	remaining: 2.48s
# 100:	learn: 0.1339655	total: 1.26s	remaining: 2.48s
# 101:	learn: 0.1324383	total: 1.27s	remaining: 2.47s
# 102:	learn: 0.1307279	total: 1.28s	remaining: 2.46s
# 103:	learn: 0.1293971	total: 1.29s	remaining: 2.44s
# 104:	learn: 0.1284196	total: 1.31s	remaining: 2.44s
# 105:	learn: 0.1269314	total: 1.32s	remaining: 2.42s
# 106:	learn: 0.1252606	total: 1.34s	remaining: 2.42s
# 107:	learn: 0.1242575	total: 1.35s	remaining: 2.4s
# 108:	learn: 0.1230863	total: 1.36s	remaining: 2.39s
# 109:	learn: 0.1213639	total: 1.38s	remaining: 2.38s
# 110:	learn: 0.1204805	total: 1.39s	remaining: 2.36s
# 111:	learn: 0.1194090	total: 1.4s	remaining: 2.35s
# 112:	learn: 0.1186416	total: 1.41s	remaining: 2.33s
# 113:	learn: 0.1174022	total: 1.42s	remaining: 2.32s
# 114:	learn: 0.1156981	total: 1.44s	remaining: 2.31s
# 115:	learn: 0.1141327	total: 1.45s	remaining: 2.3s
# 116:	learn: 0.1128159	total: 1.46s	remaining: 2.28s
# 117:	learn: 0.1118617	total: 1.47s	remaining: 2.27s
# 118:	learn: 0.1108360	total: 1.48s	remaining: 2.26s
# 119:	learn: 0.1094937	total: 1.5s	remaining: 2.25s
# 120:	learn: 0.1083626	total: 1.52s	remaining: 2.25s
# 121:	learn: 0.1076066	total: 1.54s	remaining: 2.24s
# 122:	learn: 0.1058809	total: 1.55s	remaining: 2.23s
# 123:	learn: 0.1042024	total: 1.57s	remaining: 2.23s
# 124:	learn: 0.1038600	total: 1.58s	remaining: 2.21s
# 125:	learn: 0.1030939	total: 1.59s	remaining: 2.19s
# 126:	learn: 0.1021573	total: 1.6s	remaining: 2.18s
# 127:	learn: 0.1008656	total: 1.61s	remaining: 2.17s
# 128:	learn: 0.0997425	total: 1.63s	remaining: 2.16s
# 129:	learn: 0.0982913	total: 1.64s	remaining: 2.14s
# 130:	learn: 0.0966618	total: 1.65s	remaining: 2.13s
# 131:	learn: 0.0962766	total: 1.66s	remaining: 2.12s
# 132:	learn: 0.0954469	total: 1.67s	remaining: 2.1s
# 133:	learn: 0.0945146	total: 1.68s	remaining: 2.09s
# 134:	learn: 0.0940830	total: 1.7s	remaining: 2.07s
# 135:	learn: 0.0931084	total: 1.71s	remaining: 2.06s
# 136:	learn: 0.0920978	total: 1.72s	remaining: 2.05s
# 137:	learn: 0.0914112	total: 1.74s	remaining: 2.04s
# 138:	learn: 0.0903987	total: 1.75s	remaining: 2.02s
# 139:	learn: 0.0897587	total: 1.76s	remaining: 2.01s
# 140:	learn: 0.0891923	total: 1.77s	remaining: 2s
# 141:	learn: 0.0883218	total: 1.78s	remaining: 1.99s
# 142:	learn: 0.0877781	total: 1.79s	remaining: 1.97s
# 143:	learn: 0.0873148	total: 1.81s	remaining: 1.96s
# 144:	learn: 0.0867655	total: 1.82s	remaining: 1.95s
# 145:	learn: 0.0857228	total: 1.83s	remaining: 1.93s
# 146:	learn: 0.0843796	total: 1.84s	remaining: 1.92s
# 147:	learn: 0.0835224	total: 1.86s	remaining: 1.91s
# 148:	learn: 0.0826241	total: 1.87s	remaining: 1.9s
# 149:	learn: 0.0819730	total: 1.89s	remaining: 1.89s
# 150:	learn: 0.0814746	total: 1.89s	remaining: 1.87s
# 151:	learn: 0.0808151	total: 1.91s	remaining: 1.86s
# 152:	learn: 0.0795051	total: 1.92s	remaining: 1.85s
# 153:	learn: 0.0788949	total: 1.94s	remaining: 1.83s
# 154:	learn: 0.0780483	total: 1.95s	remaining: 1.82s
# 155:	learn: 0.0777425	total: 1.96s	remaining: 1.81s
# 156:	learn: 0.0770733	total: 1.97s	remaining: 1.79s
# 157:	learn: 0.0763942	total: 1.98s	remaining: 1.78s
# 158:	learn: 0.0754382	total: 1.99s	remaining: 1.77s
# 159:	learn: 0.0751174	total: 2s	remaining: 1.75s
# 160:	learn: 0.0746016	total: 2.02s	remaining: 1.74s
# 161:	learn: 0.0739076	total: 2.03s	remaining: 1.73s
# 162:	learn: 0.0729269	total: 2.04s	remaining: 1.72s
# 163:	learn: 0.0723682	total: 2.06s	remaining: 1.7s
# 164:	learn: 0.0718480	total: 2.07s	remaining: 1.69s
# 165:	learn: 0.0711674	total: 2.08s	remaining: 1.68s
# 166:	learn: 0.0706595	total: 2.09s	remaining: 1.67s
# 167:	learn: 0.0696295	total: 2.1s	remaining: 1.65s
# 168:	learn: 0.0689860	total: 2.12s	remaining: 1.64s
# 169:	learn: 0.0685725	total: 2.13s	remaining: 1.63s
# 170:	learn: 0.0676424	total: 2.15s	remaining: 1.62s
# 171:	learn: 0.0672576	total: 2.16s	remaining: 1.61s
# 172:	learn: 0.0662607	total: 2.17s	remaining: 1.59s
# 173:	learn: 0.0660331	total: 2.18s	remaining: 1.58s
# 174:	learn: 0.0653063	total: 2.2s	remaining: 1.57s
# 175:	learn: 0.0643201	total: 2.21s	remaining: 1.56s
# 176:	learn: 0.0635770	total: 2.22s	remaining: 1.54s
# 177:	learn: 0.0630356	total: 2.23s	remaining: 1.53s
# 178:	learn: 0.0625523	total: 2.25s	remaining: 1.52s
# 179:	learn: 0.0622729	total: 2.26s	remaining: 1.5s
# 180:	learn: 0.0617745	total: 2.27s	remaining: 1.49s
# 181:	learn: 0.0611185	total: 2.28s	remaining: 1.48s
# 182:	learn: 0.0604586	total: 2.3s	remaining: 1.47s
# 183:	learn: 0.0601720	total: 2.31s	remaining: 1.46s
# 184:	learn: 0.0598060	total: 2.32s	remaining: 1.44s
# 185:	learn: 0.0594330	total: 2.34s	remaining: 1.43s
# 186:	learn: 0.0591115	total: 2.35s	remaining: 1.42s
# 187:	learn: 0.0588158	total: 2.36s	remaining: 1.41s
# 188:	learn: 0.0587036	total: 2.38s	remaining: 1.39s
# 189:	learn: 0.0581979	total: 2.39s	remaining: 1.38s
# 190:	learn: 0.0579285	total: 2.4s	remaining: 1.37s
# 191:	learn: 0.0569088	total: 2.41s	remaining: 1.35s
# 192:	learn: 0.0563737	total: 2.42s	remaining: 1.34s
# 193:	learn: 0.0556267	total: 2.44s	remaining: 1.33s
# 194:	learn: 0.0550813	total: 2.45s	remaining: 1.32s
# 195:	learn: 0.0544418	total: 2.46s	remaining: 1.3s
# 196:	learn: 0.0542095	total: 2.47s	remaining: 1.29s
# 197:	learn: 0.0536290	total: 2.48s	remaining: 1.28s
# 198:	learn: 0.0532742	total: 2.5s	remaining: 1.27s
# 199:	learn: 0.0529247	total: 2.51s	remaining: 1.25s
# 200:	learn: 0.0524059	total: 2.52s	remaining: 1.24s
# 201:	learn: 0.0519722	total: 2.53s	remaining: 1.23s
# 202:	learn: 0.0509823	total: 2.55s	remaining: 1.22s
# 203:	learn: 0.0506478	total: 2.56s	remaining: 1.21s
# 204:	learn: 0.0501448	total: 2.57s	remaining: 1.19s
# 205:	learn: 0.0497466	total: 2.59s	remaining: 1.18s
# 206:	learn: 0.0494484	total: 2.6s	remaining: 1.17s
# 207:	learn: 0.0488645	total: 2.62s	remaining: 1.16s
# 208:	learn: 0.0481834	total: 2.63s	remaining: 1.14s
# 209:	learn: 0.0476586	total: 2.64s	remaining: 1.13s
# 210:	learn: 0.0472475	total: 2.65s	remaining: 1.12s
# 211:	learn: 0.0469937	total: 2.67s	remaining: 1.11s
# 212:	learn: 0.0465739	total: 2.68s	remaining: 1.09s
# 213:	learn: 0.0462660	total: 2.69s	remaining: 1.08s
# 214:	learn: 0.0457476	total: 2.7s	remaining: 1.07s
# 215:	learn: 0.0451931	total: 2.71s	remaining: 1.05s
# 216:	learn: 0.0445650	total: 2.73s	remaining: 1.04s
# 217:	learn: 0.0441027	total: 2.74s	remaining: 1.03s
# 218:	learn: 0.0436642	total: 2.75s	remaining: 1.02s
# 219:	learn: 0.0434237	total: 2.77s	remaining: 1.01s
# 220:	learn: 0.0430997	total: 2.78s	remaining: 995ms
# 221:	learn: 0.0427888	total: 2.79s	remaining: 982ms
# 222:	learn: 0.0425625	total: 2.81s	remaining: 970ms
# 223:	learn: 0.0422420	total: 2.82s	remaining: 956ms
# 224:	learn: 0.0420312	total: 2.83s	remaining: 944ms
# 225:	learn: 0.0415282	total: 2.85s	remaining: 932ms
# 226:	learn: 0.0411542	total: 2.86s	remaining: 919ms
# 227:	learn: 0.0409698	total: 2.87s	remaining: 905ms
# 228:	learn: 0.0407613	total: 2.88s	remaining: 893ms
# 229:	learn: 0.0405600	total: 2.89s	remaining: 881ms
# 230:	learn: 0.0402726	total: 2.91s	remaining: 868ms
# 231:	learn: 0.0399243	total: 2.92s	remaining: 855ms
# 232:	learn: 0.0397157	total: 2.93s	remaining: 842ms
# 233:	learn: 0.0395163	total: 2.94s	remaining: 830ms
# 234:	learn: 0.0390159	total: 2.96s	remaining: 818ms
# 235:	learn: 0.0387632	total: 2.97s	remaining: 805ms
# 236:	learn: 0.0384140	total: 2.98s	remaining: 792ms
# 237:	learn: 0.0379156	total: 2.99s	remaining: 780ms
# 37:	learn: 0.2939912	total: 594ms	remaining: 4.1s
# 38:	learn: 0.2921151	total: 605ms	remaining: 4.05s
# 39:	learn: 0.2885505	total: 614ms	remaining: 3.99s
# 40:	learn: 0.2872476	total: 623ms	remaining: 3.94s
# 41:	learn: 0.2831085	total: 633ms	remaining: 3.89s
# 42:	learn: 0.2794479	total: 643ms	remaining: 3.84s
# 43:	learn: 0.2769694	total: 652ms	remaining: 3.79s
# 44:	learn: 0.2745557	total: 662ms	remaining: 3.75s
# 45:	learn: 0.2717985	total: 672ms	remaining: 3.71s
# 46:	learn: 0.2686078	total: 683ms	remaining: 3.67s
# 47:	learn: 0.2618105	total: 694ms	remaining: 3.64s
# 48:	learn: 0.2585797	total: 703ms	remaining: 3.6s
# 49:	learn: 0.2565276	total: 713ms	remaining: 3.56s
# 50:	learn: 0.2528362	total: 724ms	remaining: 3.54s
# 51:	learn: 0.2497648	total: 736ms	remaining: 3.51s
# 52:	learn: 0.2479198	total: 745ms	remaining: 3.47s
# 53:	learn: 0.2441871	total: 755ms	remaining: 3.44s
# 54:	learn: 0.2415158	total: 764ms	remaining: 3.4s
# 55:	learn: 0.2368020	total: 778ms	remaining: 3.39s
# 56:	learn: 0.2332086	total: 788ms	remaining: 3.36s
# 57:	learn: 0.2308498	total: 797ms	remaining: 3.33s
# 58:	learn: 0.2273449	total: 807ms	remaining: 3.29s
# 59:	learn: 0.2255584	total: 816ms	remaining: 3.27s
# 60:	learn: 0.2231400	total: 826ms	remaining: 3.24s
# 61:	learn: 0.2204736	total: 836ms	remaining: 3.21s
# 62:	learn: 0.2174512	total: 847ms	remaining: 3.18s
# 63:	learn: 0.2158009	total: 856ms	remaining: 3.15s
# 64:	learn: 0.2116369	total: 865ms	remaining: 3.13s
# 65:	learn: 0.2085106	total: 875ms	remaining: 3.1s
# 66:	learn: 0.2059707	total: 885ms	remaining: 3.08s
# 67:	learn: 0.2042590	total: 894ms	remaining: 3.05s
# 68:	learn: 0.2028615	total: 904ms	remaining: 3.02s
# 69:	learn: 0.2019908	total: 913ms	remaining: 3s
# 70:	learn: 0.1999584	total: 924ms	remaining: 2.98s
# 71:	learn: 0.1974484	total: 934ms	remaining: 2.96s
# 72:	learn: 0.1946235	total: 945ms	remaining: 2.94s
# 73:	learn: 0.1928171	total: 955ms	remaining: 2.92s
# 74:	learn: 0.1906494	total: 965ms	remaining: 2.89s
# 75:	learn: 0.1864557	total: 981ms	remaining: 2.89s
# 76:	learn: 0.1843566	total: 991ms	remaining: 2.87s
# 77:	learn: 0.1816258	total: 1s	remaining: 2.85s
# 78:	learn: 0.1804516	total: 1.01s	remaining: 2.82s
# 79:	learn: 0.1780272	total: 1.02s	remaining: 2.8s
# 80:	learn: 0.1762581	total: 1.03s	remaining: 2.78s
# 81:	learn: 0.1722366	total: 1.04s	remaining: 2.76s
# 82:	learn: 0.1711543	total: 1.05s	remaining: 2.74s
# 83:	learn: 0.1697802	total: 1.06s	remaining: 2.72s
# 84:	learn: 0.1660475	total: 1.07s	remaining: 2.7s
# 85:	learn: 0.1642891	total: 1.08s	remaining: 2.68s
# 86:	learn: 0.1621166	total: 1.08s	remaining: 2.66s
# 87:	learn: 0.1609514	total: 1.09s	remaining: 2.64s
# 88:	learn: 0.1591388	total: 1.1s	remaining: 2.62s
# 89:	learn: 0.1570179	total: 1.11s	remaining: 2.6s
# 90:	learn: 0.1554484	total: 1.12s	remaining: 2.58s
# 91:	learn: 0.1542285	total: 1.13s	remaining: 2.56s
# 92:	learn: 0.1530043	total: 1.14s	remaining: 2.54s
# 93:	learn: 0.1518073	total: 1.15s	remaining: 2.52s
# 94:	learn: 0.1509131	total: 1.16s	remaining: 2.51s
# 95:	learn: 0.1494993	total: 1.17s	remaining: 2.5s
# 96:	learn: 0.1479450	total: 1.18s	remaining: 2.48s
# 97:	learn: 0.1461983	total: 1.19s	remaining: 2.46s
# 98:	learn: 0.1441478	total: 1.21s	remaining: 2.45s
# 99:	learn: 0.1431962	total: 1.21s	remaining: 2.43s
# 100:	learn: 0.1420768	total: 1.22s	remaining: 2.41s
# 101:	learn: 0.1412644	total: 1.24s	remaining: 2.4s
# 102:	learn: 0.1397773	total: 1.25s	remaining: 2.38s
# 103:	learn: 0.1382901	total: 1.26s	remaining: 2.38s
# 104:	learn: 0.1358655	total: 1.28s	remaining: 2.37s
# 105:	learn: 0.1346914	total: 1.29s	remaining: 2.37s
# 106:	learn: 0.1336723	total: 1.3s	remaining: 2.35s
# 107:	learn: 0.1324990	total: 1.32s	remaining: 2.34s
# 108:	learn: 0.1308150	total: 1.33s	remaining: 2.34s
# 109:	learn: 0.1298874	total: 1.35s	remaining: 2.33s
# 110:	learn: 0.1285687	total: 1.37s	remaining: 2.33s
# 111:	learn: 0.1275780	total: 1.38s	remaining: 2.31s
# 112:	learn: 0.1257887	total: 1.39s	remaining: 2.3s
# 113:	learn: 0.1251170	total: 1.4s	remaining: 2.28s
# 114:	learn: 0.1227812	total: 1.42s	remaining: 2.28s
# 115:	learn: 0.1213434	total: 1.43s	remaining: 2.27s
# 116:	learn: 0.1194774	total: 1.44s	remaining: 2.26s
# 117:	learn: 0.1180614	total: 1.45s	remaining: 2.24s
# 118:	learn: 0.1174922	total: 1.47s	remaining: 2.23s
# 119:	learn: 0.1171684	total: 1.47s	remaining: 2.21s
# 120:	learn: 0.1163497	total: 1.48s	remaining: 2.19s
# 121:	learn: 0.1157181	total: 1.49s	remaining: 2.18s
# 122:	learn: 0.1142998	total: 1.5s	remaining: 2.16s
# 123:	learn: 0.1128869	total: 1.51s	remaining: 2.15s
# 124:	learn: 0.1110943	total: 1.52s	remaining: 2.13s
# 125:	learn: 0.1101832	total: 1.53s	remaining: 2.11s
# 126:	learn: 0.1089491	total: 1.54s	remaining: 2.1s
# 127:	learn: 0.1081081	total: 1.55s	remaining: 2.08s
# 128:	learn: 0.1070615	total: 1.56s	remaining: 2.07s
# 129:	learn: 0.1068250	total: 1.57s	remaining: 2.05s
# 130:	learn: 0.1058129	total: 1.58s	remaining: 2.04s
# 131:	learn: 0.1053555	total: 1.59s	remaining: 2.02s
# 132:	learn: 0.1040309	total: 1.6s	remaining: 2.01s
# 133:	learn: 0.1031032	total: 1.61s	remaining: 2s
# 134:	learn: 0.1027000	total: 1.62s	remaining: 1.99s
# 135:	learn: 0.1020628	total: 1.64s	remaining: 1.98s
# 136:	learn: 0.1013353	total: 1.65s	remaining: 1.96s
# 137:	learn: 0.0994339	total: 1.66s	remaining: 1.95s
# 138:	learn: 0.0988515	total: 1.67s	remaining: 1.93s
# 139:	learn: 0.0975093	total: 1.68s	remaining: 1.92s
# 140:	learn: 0.0963076	total: 1.69s	remaining: 1.91s
# 141:	learn: 0.0955238	total: 1.7s	remaining: 1.89s
# 142:	learn: 0.0944647	total: 1.72s	remaining: 1.89s
# 143:	learn: 0.0935163	total: 1.74s	remaining: 1.88s
# 144:	learn: 0.0923214	total: 1.76s	remaining: 1.88s
# 145:	learn: 0.0912749	total: 1.78s	remaining: 1.87s
# 146:	learn: 0.0907684	total: 1.81s	remaining: 1.89s
# 147:	learn: 0.0896108	total: 1.85s	remaining: 1.9s
# 148:	learn: 0.0887371	total: 1.88s	remaining: 1.9s
# 149:	learn: 0.0872562	total: 1.89s	remaining: 1.89s
# 150:	learn: 0.0862406	total: 1.91s	remaining: 1.89s
# 151:	learn: 0.0858893	total: 1.93s	remaining: 1.88s
# 152:	learn: 0.0851000	total: 1.94s	remaining: 1.87s
# 153:	learn: 0.0839466	total: 1.96s	remaining: 1.85s
# 154:	learn: 0.0831261	total: 1.97s	remaining: 1.84s
# 155:	learn: 0.0826350	total: 1.98s	remaining: 1.83s
# 156:	learn: 0.0816671	total: 2s	remaining: 1.82s
# 157:	learn: 0.0808149	total: 2.01s	remaining: 1.81s
# 158:	learn: 0.0804770	total: 2.02s	remaining: 1.79s
# 159:	learn: 0.0797625	total: 2.03s	remaining: 1.78s
# 160:	learn: 0.0792187	total: 2.04s	remaining: 1.76s
# 161:	learn: 0.0785188	total: 2.06s	remaining: 1.75s
# 162:	learn: 0.0777799	total: 2.07s	remaining: 1.74s
# 163:	learn: 0.0775241	total: 2.08s	remaining: 1.72s
# 164:	learn: 0.0767747	total: 2.09s	remaining: 1.71s
# 165:	learn: 0.0757700	total: 2.1s	remaining: 1.69s
# 166:	learn: 0.0749300	total: 2.11s	remaining: 1.68s
# 167:	learn: 0.0742947	total: 2.12s	remaining: 1.66s
# 168:	learn: 0.0737167	total: 2.13s	remaining: 1.65s
# 169:	learn: 0.0733694	total: 2.13s	remaining: 1.63s
# 170:	learn: 0.0725504	total: 2.15s	remaining: 1.62s
# 171:	learn: 0.0717482	total: 2.16s	remaining: 1.61s
# 172:	learn: 0.0715217	total: 2.17s	remaining: 1.59s
# 173:	learn: 0.0709057	total: 2.18s	remaining: 1.58s
# 174:	learn: 0.0699427	total: 2.19s	remaining: 1.57s
# 175:	learn: 0.0695964	total: 2.2s	remaining: 1.55s
# 176:	learn: 0.0690250	total: 2.22s	remaining: 1.54s
# 177:	learn: 0.0683422	total: 2.23s	remaining: 1.53s
# 178:	learn: 0.0680049	total: 2.24s	remaining: 1.52s
# 179:	learn: 0.0671780	total: 2.25s	remaining: 1.5s
# 180:	learn: 0.0665486	total: 2.26s	remaining: 1.49s
# 181:	learn: 0.0655381	total: 2.27s	remaining: 1.47s
# 182:	learn: 0.0652026	total: 2.28s	remaining: 1.46s
# 183:	learn: 0.0646128	total: 2.3s	remaining: 1.45s
# 184:	learn: 0.0642841	total: 2.31s	remaining: 1.43s
# 185:	learn: 0.0635946	total: 2.31s	remaining: 1.42s
# 186:	learn: 0.0630733	total: 2.33s	remaining: 1.41s
# 187:	learn: 0.0625180	total: 2.33s	remaining: 1.39s
# 188:	learn: 0.0622256	total: 2.35s	remaining: 1.38s
# 189:	learn: 0.0614471	total: 2.36s	remaining: 1.37s
# 190:	learn: 0.0609709	total: 2.38s	remaining: 1.36s
# 191:	learn: 0.0602173	total: 2.39s	remaining: 1.34s
# 192:	learn: 0.0596144	total: 2.4s	remaining: 1.33s
# 193:	learn: 0.0591067	total: 2.41s	remaining: 1.32s
# 194:	learn: 0.0585592	total: 2.42s	remaining: 1.3s
# 195:	learn: 0.0578826	total: 2.44s	remaining: 1.3s
# 196:	learn: 0.0572729	total: 2.46s	remaining: 1.28s
# 197:	learn: 0.0567133	total: 2.47s	remaining: 1.27s
# 198:	learn: 0.0561310	total: 2.48s	remaining: 1.26s
# 199:	learn: 0.0555158	total: 2.49s	remaining: 1.25s
# 200:	learn: 0.0552666	total: 2.51s	remaining: 1.23s
# 201:	learn: 0.0549787	total: 2.52s	remaining: 1.22s
# 202:	learn: 0.0546188	total: 2.53s	remaining: 1.21s
# 203:	learn: 0.0540295	total: 2.54s	remaining: 1.2s
# 204:	learn: 0.0536346	total: 2.56s	remaining: 1.19s
# 205:	learn: 0.0527712	total: 2.57s	remaining: 1.17s
# 206:	learn: 0.0524612	total: 2.58s	remaining: 1.16s
# 207:	learn: 0.0521069	total: 2.59s	remaining: 1.15s
# 208:	learn: 0.0517637	total: 2.6s	remaining: 1.13s
# 209:	learn: 0.0512197	total: 2.61s	remaining: 1.12s
# 210:	learn: 0.0508602	total: 2.63s	remaining: 1.11s
# 211:	learn: 0.0502666	total: 2.64s	remaining: 1.09s
# 212:	learn: 0.0500167	total: 2.65s	remaining: 1.08s
# 213:	learn: 0.0496198	total: 2.66s	remaining: 1.07s
# 214:	learn: 0.0492818	total: 2.67s	remaining: 1.05s
# 215:	learn: 0.0487057	total: 2.68s	remaining: 1.04s
# 216:	learn: 0.0482113	total: 2.69s	remaining: 1.03s
# 217:	learn: 0.0475757	total: 2.69s	remaining: 1.01s
# 218:	learn: 0.0472750	total: 2.71s	remaining: 1s
# 219:	learn: 0.0465902	total: 2.72s	remaining: 988ms
# 220:	learn: 0.0461200	total: 2.73s	remaining: 975ms
# 221:	learn: 0.0455756	total: 2.74s	remaining: 961ms
# 222:	learn: 0.0451851	total: 2.75s	remaining: 948ms
# 271:	learn: 0.0316165	total: 3.37s	remaining: 347ms
# 272:	learn: 0.0313948	total: 3.38s	remaining: 335ms
# 273:	learn: 0.0311935	total: 3.39s	remaining: 322ms
# 274:	learn: 0.0308295	total: 3.41s	remaining: 310ms
# 275:	learn: 0.0307150	total: 3.44s	remaining: 299ms
# 276:	learn: 0.0305584	total: 3.45s	remaining: 287ms
# 277:	learn: 0.0302211	total: 3.47s	remaining: 275ms
# 278:	learn: 0.0299716	total: 3.49s	remaining: 263ms
# 279:	learn: 0.0296492	total: 3.54s	remaining: 253ms
# 280:	learn: 0.0294811	total: 3.56s	remaining: 241ms
# 281:	learn: 0.0292915	total: 3.58s	remaining: 229ms
# 282:	learn: 0.0292018	total: 3.59s	remaining: 216ms
# 283:	learn: 0.0290807	total: 3.6s	remaining: 203ms
# 284:	learn: 0.0288405	total: 3.61s	remaining: 190ms
# 285:	learn: 0.0286272	total: 3.62s	remaining: 177ms
# 286:	learn: 0.0284027	total: 3.63s	remaining: 165ms
# 287:	learn: 0.0281295	total: 3.65s	remaining: 152ms
# 288:	learn: 0.0279915	total: 3.67s	remaining: 140ms
# 289:	learn: 0.0276740	total: 3.68s	remaining: 127ms
# 290:	learn: 0.0275688	total: 3.69s	remaining: 114ms
# 291:	learn: 0.0274687	total: 3.71s	remaining: 102ms
# 292:	learn: 0.0273141	total: 3.71s	remaining: 88.7ms
# 293:	learn: 0.0271392	total: 3.72s	remaining: 76ms
# 294:	learn: 0.0270433	total: 3.73s	remaining: 63.3ms
# 295:	learn: 0.0267386	total: 3.74s	remaining: 50.6ms
# 296:	learn: 0.0264641	total: 3.76s	remaining: 37.9ms
# 297:	learn: 0.0263930	total: 3.77s	remaining: 25.3ms
# 298:	learn: 0.0262927	total: 3.8s	remaining: 12.7ms
# 299:	learn: 0.0261498	total: 3.81s	remaining: 0us

# %%
cv_df.groupby('model_name').accuracy.mean()
# Out:
# model_name
# AdaBoostClassifier            0.758774
# CatBoostClassifier            0.810181
# GradientBoostingClassifier    0.805383
# RandomForestClassifier        0.823813
# XGBClassifier                 0.799465
# Name: accuracy, dtype: float64

# %%
model = RandomForestClassifier(n_estimators=100)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

# %% [markdown]
# ##### Avaliação do modelo

# %% [markdown]
# Nesta etapa, após o treinamento dos modelos faremos a avaliação do mesmo, observando métricas como Score, Recall, Precision, F1-Score e Kappa.
#
# Observaremos todas essas métricas uma vez que podemos ter um modelo com um bías e se levarmos somente uma métrica como medida de avaliação do modelo, podemos nos equivocar na sua real precisão.
#
# Todos as métricas vão de 0 a 1, lembrando que quanto mais próximo de 1 melhor.

# %%
def metrics(X_test, y_test, metric_type):
    test_preds = model.predict(X_test)

    test_score = round(model.score(X_test, y_test),2)
    test_rec_s = round(recall_score(y_test, test_preds), 2)
    test_prec_s = round(precision_score(y_test, test_preds, 2))
    test_f1 = round(f1_score(y_test, test_preds), 2)
    test_kappa = round(cohen_kappa_score(y_test, test_preds), 2)

    print("Métricas do modelo Gradient Boosting no dataset de", metric_type)
    print('\n')
    print('score: ', test_score)
    print('recall: ', test_rec_s)
    print('prec: ', test_prec_s)
    print('f1: ', test_f1)
    print('kappa: ', test_kappa)
    print('')

# %% [markdown]
# Entendimento sobre algumas métricas aqui apresentadas.
#
# Accuracy - True positive / total rows
#
# f1 Score - Média harmônica entre precision e recall. Boa para classes desproporcionais.
#
# Precision - Número de registros classificados como sendo de uma classe e que realmente são daquela classe, divido pela soma entre este número e a soma dos que foram classificados nesta classe mas pertencem a outra. True positive/true positive+false positive.
#
# Recall - Número de registros classificados e que realmente pertencem a esta classe, dividido pela quantidade de registros que temos nesta classe. True positive / positive.
#
# Kappa Statistics - Métrica que avalia o nível de concordância de uma classificação, concordância total teriamos um valor igual a 1, bem como podemose ter baixa ou concordância negativa.

# %%
metrics(X_test, y_test, "Teste"), metrics(X_valid, y_valid, "Validação")
# Out:
# Métricas do modelo Gradient Boosting no dataset de Teste
#
#
# score:  0.85
# recall:  0.87
# prec:  1.0
# f1:  0.88
# kappa:  0.68
#
# Métricas do modelo Gradient Boosting no dataset de Validação
#
#
# score:  0.83
# recall:  0.89
# prec:  1.0
# f1:  0.87
# kappa:  0.63
# (None, None)

# %% [markdown]
# ##### Matriz de confusão

# %% [markdown]
# A matriz de confusão nos fornece a visão de quanto o modelo errou e acertou.
#
# Podemos notar que a maior parte dos erros esta relacionado a classe 1, pois temos uma quantidade menor de dados nesta classe, 1267 contra 5190 na classe 0, observando precision, recall e f1-score de cada classe podemos comprovar o comportamento de que o modelo aprendeu mais a classe com mais observações.

# %%
print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# [[122  29]
#  [ 32 221]]
#               precision    recall  f1-score   support
#
#            0       0.79      0.81      0.80       151
#            1       0.88      0.87      0.88       253
#
#     accuracy                           0.85       404
#    macro avg       0.84      0.84      0.84       404
# weighted avg       0.85      0.85      0.85       404

# %% [markdown]
# ##### Curva ROC dataset de teste

# %% [markdown]
# A curva roc (receiver operating characteristic) nos ajuda a visualizar o quão bom pode ser um modelo de classificação binária. Temos duas métricas para analisar, a taxa de Falso positivo e taxa de verdadeiro positivo.
#
# A idéia é ter um auc cobrindo a maior parte possível do gráfico, e ter um valor mais próximo de 1, no nosso caso temos um auc de 0.82, o que nos mostra que nosso modelo não é excelente.

# %%
false_positive_rate, true_positive_rate,thresholds = roc_curve(y_pred, y_test)
roc_auc = auc(false_positive_rate,true_positive_rate)

plt.title('Roc Curve XGBoost Model test dataset')
plt.plot(false_positive_rate,true_positive_rate,'b', label='AUC = %0.2f'%roc_auc)
plt.legend(loc='lower right')
plt.plot([0,1],[0,1],'r--')
plt.ylabel('True positive rate')
plt.xlabel('False positive rate')
plt.show()

# %% [markdown]
# ##### Features mais importantes

# %% [markdown]
# Aqui temos as features elencadas como mais importantes pelo nosso modelo, podemos ver que a mais importante delas é o teor alcólico, seguido pelas demais variáveis que tem importância muito próxima.

# %%
importances = pd.DataFrame({'feature':X_test.columns,'importance':np.round(model.feature_importances_,3)})
importances = importances.sort_values('importance',ascending=False).set_index('feature')
importances.plot.bar()

# %% [markdown]
# Nosso dataset apesar de ter sido modificado sua variável target para binária, sofreu poucas alterações nas demais features, não havia muito espaço para criação de novas features, talvez em um próximo passo podemos desenvolver um modelo mais robusto talvez pensar em usar técnicas de undersampling ou oversampling para suprir o desbalanceamento das classes preditoras, bem como modelos com suporte a classes desbalanceadas.
